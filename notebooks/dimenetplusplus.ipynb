# %% [markdown]
# ## DimeNet++

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(root)

# %% [markdown]
# To run the notebook on Google Colab (uncomment the shell commands. Silenced as safeguard):

# %%
# --- Remove any existing conflicting installs ---
# !pip uninstall -y torch torchvision torchaudio torch-scatter torch-sparse torch-cluster torch-spline-conv torch-geometric

# --- Install PyTorch with CUDA 12.1 (compatible with PyG) ---
# %pip install torch==2.3.0+cu121 torchvision==0.18.0+cu121 torchaudio==2.3.0+cu121 \
#     --extra-index-url https://download.pytorch.org/whl/cu121 --quiet

# --- Install the PyG dependencies (compiled wheels for PyTorch 2.3.0 + cu121) ---
# %pip install torch-scatter torch-sparse torch-cluster torch-spline-conv \
#     -f https://pytorch-geometric.com/whl/torch-2.3.0+cu121.html --quiet

# --- Install torch-geometric itself ---
# %pip install torch-geometric --quiet

# --- Verify installation ---
import torch
import torch_geometric
import torch_cluster

print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("PyG:", torch_geometric.__version__)
print("torch-cluster:", torch_cluster.__version__)
# Out:
# Torch: 2.8.0+cu128
# CUDA available: True
# CUDA version: 12.8
# PyG: 2.7.0
# torch-cluster: 1.6.3+pt28cu128

# %%
import torch
from torch_geometric.loader import DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

import scripts.data.dataset as ds
from scripts.model.dimenetplusplus import DimeNetPlusPlusModel
from scripts.train.train import train_one_epoch
from scripts.evaluate.evaluate import evaluate, compare_ytrue_ypred

# %% [markdown]
# Select GPU if run in Google Colab

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# ### Preparing the dataset

# %% [markdown]
# Download the dataset

# %%
dataset = ds.load_qm9_dataset(root=f"{root}/data/QM9")
ds.describe_dataset(dataset)
# Out:
# Dataset: QM9(130831):
# [====================]
# Number of graphs: 130831
# Number of features: 11
# Number of classes: 19
#
# First node data:
# [====================]
# Data(x=[5, 11], edge_index=[2, 8], edge_attr=[8, 4], y=[1, 19], pos=[5, 3], idx=[1], name='gdb_1', z=[5])
# Number of nodes: 5
# Number of edges: 8
# Average node degree: 1.60
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True

# %% [markdown]
# Split the dataset into training and test sets

# %%
train_dataset, test_dataset = ds.split_dataset(dataset, training_perc=0.9)
# Out:
# Number of training graphs: 117747
# Number of test graphs: 13084

# %% [markdown]
# Normalize the target property in the training set

# %%
target_idx = 11
train_mean, train_std = ds.normalize_train_set(train_dataset, target_idx=target_idx)
train_mean = train_mean.to(device)
train_std = train_std.to(device)
# Out:
# Target statistics - Mean: 31.6212, Std: 4.0685

# %% [markdown]
# Create the DataLoaders for the training and test sets

# %%
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# ### Training

# %%
# Model, optimizer, loss, scheduler
model = DimeNetPlusPlusModel().model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-5)
criterion = torch.nn.L1Loss()
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5, patience=5)

# Training loop with early stopping and checkpointing
max_epochs = 500
patience = 20
min_delta = 1e-4
best_val = float('inf')
epochs_no_improve = 0
save_path = f"{root}/models/dimenetplusplus.pt"

print("Starting training...")
for epoch in range(1, max_epochs + 1):

    train_loss = train_one_epoch(
        model, train_loader, optimizer, criterion, device,
        train_mean, train_std, target_idx, model_type="dimenet")
    
    train_mae = evaluate(
        model, train_loader, device, train_mean,
        train_std, target_idx, model_type="dimenet")
    val_mae = evaluate(
        model, test_loader, device, train_mean,
        train_std, target_idx, model_type="dimenet")
    
    scheduler.step(val_mae)

    # Check for improvement and checkpoint
    if val_mae < best_val - min_delta:
        best_val = val_mae
        epochs_no_improve = 0
        # torch.save(model.state_dict(), save_path)
        improved = " *"
    else:
        epochs_no_improve += 1
        improved = ""

    if epoch % 5 == 0 or epochs_no_improve == 0:
        print(f"[*] Epoch {epoch:03d}  Train loss: {train_loss:.4f}  Train MAE: {train_mae:.4f}  Val MAE: {val_mae:.4f}{improved}")

    if epochs_no_improve >= patience:
        print(f"Early stopping at epoch {epoch} (no val MAE improvement for {patience} epochs).")
        break


# Load best model for final evaluation
model.load_state_dict(torch.load(save_path))
final_val = evaluate(
        model, test_loader, device, train_mean,
        train_std, target_idx, model_type="gcn")

print(f"Best validation MAE: {best_val:.4f}")
print(f"Final evaluated MAE: {final_val:.4f}")
print(f"Test set mean: {train_mean:.4f}, std: {train_std:.4f}")
print(f"Relative MAE: {(best_val/train_std.abs()):.4f} standard deviations")

# Compare to baseline (predicting mean)
baseline_mae = train_std.abs().item()
print(f"Baseline MAE (predicting mean): {baseline_mae:.4f}")
print(f"Improvement over baseline: {(baseline_mae/best_val):.2f}x")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Model, optimizer, loss, scheduler
# ----> 2 model = DimeNetPlusPlusModel().to(device)
#       3 optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-5)
#       4 criterion = torch.nn.L1Loss()
#
# File ~/Documents/projects/qm9/scripts/model/dimenetplusplus.py:13, in DimeNetPlusPlusModel.__init__(self)
#      11 def __init__(self):
#      12     super().__init__()
# ---> 13     self.model = DimeNetPlusPlus(
#      14     hidden_channels=128,
#      15     out_channels=1,
#      16     num_blocks=4,
#      17     int_emb_size=64,
#      18     basis_emb_size=8,
#      19     out_emb_channels=256,
#      20     num_spherical=7,
#      21     num_radial=6,
#      22     cutoff=5.0,
#      23     envelope_exponent=5,
#      24     num_before_skip=1,
#      25     num_after_skip=2,
#      26     num_output_layers=3
#      27 )
#
# File ~/miniconda3/envs/torch28/lib/python3.13/site-packages/torch_geometric/nn/models/dimenet.py:789, in DimeNetPlusPlus.__init__(self, hidden_channels, out_channels, num_blocks, int_emb_size, basis_emb_size, out_emb_channels, num_spherical, num_radial, cutoff, max_num_neighbors, envelope_exponent, num_before_skip, num_after_skip, num_output_layers, act, output_initializer)
#     768 def __init__(
#     769     self,
#     770     hidden_channels: int,
#    (...)    785     output_initializer: str = 'zeros',
#     786 ):
#     787     act = activation_resolver(act)
# --> 789     super().__init__(
#     790         hidden_channels=hidden_channels,
#     791         out_channels=out_channels,
#     792         num_blocks=num_blocks,
#     793         num_bilinear=1,
#     794         num_spherical=num_spherical,
#     795         num_radial=num_radial,
#     796         cutoff=cutoff,
#     797         max_num_neighbors=max_num_neighbors,
#     798         envelope_exponent=envelope_exponent,
#     799         num_before_skip=num_before_skip,
#     800         num_after_skip=num_after_skip,
#     801         num_output_layers=num_output_layers,
#     802         act=act,
#     803         output_initializer=output_initializer,
#     804     )
#     806     # We are re-using the RBF, SBF and embedding layers of `DimeNet` and
#     807     # redefine output_block and interaction_block in DimeNet++.
#     808     # Hence, it is to be noted that in the above initialization, the
#     809     # variable `num_bilinear` does not have any purpose as it is used
#     810     # solely in the `OutputBlock` of DimeNet:
#     811     self.output_blocks = torch.nn.ModuleList([
#     812         OutputPPBlock(
#     813             num_radial,
#    (...)    820         ) for _ in range(num_blocks + 1)
#     821     ])
#
# File ~/miniconda3/envs/torch28/lib/python3.13/site-packages/torch_geometric/nn/models/dimenet.py:530, in DimeNet.__init__(self, hidden_channels, out_channels, num_blocks, num_bilinear, num_spherical, num_radial, cutoff, max_num_neighbors, envelope_exponent, num_before_skip, num_after_skip, num_output_layers, act, output_initializer)
#     527 self.num_blocks = num_blocks
#     529 self.rbf = BesselBasisLayer(num_radial, cutoff, envelope_exponent)
# --> 530 self.sbf = SphericalBasisLayer(num_spherical, num_radial, cutoff,
#     531                                envelope_exponent)
#     533 self.emb = EmbeddingBlock(num_radial, hidden_channels, act)
#     535 self.output_blocks = torch.nn.ModuleList([
#     536     OutputBlock(
#     537         num_radial,
#    (...)    543     ) for _ in range(num_blocks + 1)
#     544 ])
#
# File ~/miniconda3/envs/torch28/lib/python3.13/site-packages/torch_geometric/nn/models/dimenet.py:110, in SphericalBasisLayer.__init__(self, num_spherical, num_radial, cutoff, envelope_exponent)
#     108     self.sph_funcs.append(sph)
#     109 for j in range(num_radial):
# --> 110     bessel = sym.lambdify([x], bessel_forms[i][j], modules)
#     111     self.bessel_funcs.append(bessel)
#
# File ~/miniconda3/envs/torch28/lib/python3.13/site-packages/sympy/utilities/lambdify.py:894, in lambdify(args, expr, modules, printer, use_imps, dummify, cse, docstring_limit)
#     892 else:
#     893     cses, _expr = (), expr
# --> 894 funcstr = funcprinter.doprint(funcname, iterable_args, _expr, cses=cses)
#     896 # Collect the module imports from the code printers.
#     897 imp_mod_lines = []
#
# File ~/miniconda3/envs/torch28/lib/python3.13/site-packages/sympy/utilities/lambdify.py:1197, in _EvaluatorPrinter.doprint(self, funcname, args, expr, cses)
#    1195 # Subs may appear in expressions generated by .diff()
#    1196 subs_assignments = []
# -> 1197 expr = self._handle_Subs(expr, out=subs_assignments)
#    1198 for lhs, rhs in subs_assignments:
#    1199     funcbody.append('{} = {}'.format(self._exprrepr(lhs), self._exprrepr(rhs)))
#
# File ~/miniconda3/envs/torch28/lib/python3.13/site-packages/sympy/utilities/lambdify.py:1331, in _EvaluatorPrinter._handle_Subs(self, expr, out)
#    1328     return ex.xreplace(safe)
#    1330 if isinstance(expr, (Basic, MatrixBase)):
# -> 1331     expr = expr.replace(Subs, _replace)
#    1332 elif iterable(expr):
#    1333     expr = type(expr)([self._handle_Subs(e, out) for e in expr])
#
# File ~/miniconda3/envs/torch28/lib/python3.13/site-packages/sympy/core/basic.py:1542, in Basic.replace(self, query, value, map, simultaneous, exact)
#    1539     # no success
#    1540     return False
# -> 1542 def replace(self, query, value, map=False, simultaneous=True, exact=None) -> Basic:
#    1543     """
#    1544     Replace matching subexpressions of ``self`` with ``value``.
#    1545
#    (...)   1702
#    1703     """
#    1705     try:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Testing the performance

# %%
model = DimeNetPlusPlusModel().model
model.load_state_dict(torch.load(f'{root}/models/dimenetplusplus.pt'))
model.to(device)

test_mae = evaluate(
        model, test_loader, device, train_mean,
        train_std, target_idx, model_type="dimenet")

print(f"Test set MAE: {test_mae:.4f}")
print(f"Test set mean: {train_mean:.4f}, std: {train_std:.4f}")
print(f"Relative MAE: {(test_mae/train_std.abs()):.4f} standard deviations")
# Out:
# Test set MAE: 0.0628
# Test set mean: 31.6212, std: 4.0685
# Relative MAE: 0.0154 standard deviations

# %%
ytrue, ypred = compare_ytrue_ypred(
        model, test_loader, device, train_mean,
        train_std, target_idx, model_type="dimenet")
ytrue = torch.cat(ytrue).cpu().numpy()
ypred = torch.cat(ypred).cpu().numpy()

# Calculate R² score
r2 = r2_score(ytrue, ypred)
print(f"R² score on test set: {r2:.4f}")

# Plot true vs predicted valuesS
plt.scatter(ytrue, ypred, alpha=0.3, s=3)
plt.plot([ytrue.min(), ytrue.max()], [ytrue.min(), ytrue.max()], 'r--')
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("True vs Predicted Values on Test Set")
plt.show()
# Out:
# R² score on test set: 0.9989
